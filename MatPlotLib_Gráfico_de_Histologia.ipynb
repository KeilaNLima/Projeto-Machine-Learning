# %% [markdown]
# <a href="https://colab.research.google.com/github/KeilaNLima/Material-da-Disciplina-prof.-Ricardo/blob/Gr%C3%A1fico_histograma/MatPlotLib_Gr%C3%A1fico_de_Histologia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criando gráfico de histologia com a biblioteca MatPlotLib
# Keila Nunes de Lima 
# 15/ abri/2023

# %%
# Importando bibliotecas
import numpy as np
import matplotlib.pyplot as plt

# %%
# Criando uma variavel X com numeros aleatorios
x = np.random.rand(2000)

# %%
# Criando a histologia
plt.hist(x)
plt.xlabel('x')
plt.ylabel('contagem')
plt.show()

# %%
# Alterando o numero de Bins
plt.hist(x,bins=10)
plt.xlabel('x')
plt.ylabel('Contagem')
plt.title('bins=10')
plt.show()

# %%
plt.hist(x,bins=30)
plt.xlabel('x')
plt.ylabel('Contagem')
plt.title('bins=30')
plt.show()

# %%
plt.hist(x,bins=60)
plt.xlabel(x)
plt.ylabel('contagem')
plt.title('bins=60')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
#  Alterando a cor
plt.hist(x,bins=60,color='green')
plt.xlabel('x')
plt.ylabel('Contagem')
plt.title('bins=60')
plt.show()

# %%
plt.hist(x,bins=60,color='green', edgecolor='blue')
plt.xlabel('x')
plt.ylabel('Contagem')
plt.title('bins=60')
plt.show()

# %%
# Mutiplos histogramas na mesma imagem
x1 = np.random.normal(0,1,size = 800)
x2 = np.random.normal(3,1,size = 800)
x3 = np.random.normal(5,1,size = 800)

# %%
plt.hist(x1,bins=10,color='black')
plt.hist(x2,bins=10,color='blue')
plt.hist(x3,bins=10,color='green')
plt.xlabel(x)
plt.ylabel('contagem')
plt.title('Multiplos histogramas')
plt.show()

# %%
# triplos histogramas na mesma imagem
x1 = np.random.normal(0,1,size = 800)
x2 = np.random.normal(3,1,size = 800)
x3 = np.random.normal(5,1,size = 800)
x4 = np.random.normal(7,1,size = 800)

# %%
plt.hist(x1,bins=10,color='purple')
plt.hist(x2,bins=10,color='blue')
plt.hist(x3,bins=10,color='green')
plt.hist(x4,bins=10,color='orange')
plt.xlabel(x)
plt.ylabel('contagem')
plt.title('triplos histogramas')
plt.show()

# %%
# Distribuiçao cumulativa

# %%
x = np.random.rand(2000)

# %%
plt.hist(x,bins=20,color='violet', edgecolor='red',cumulative=True)
plt.xlabel('x')
plt.ylabel('Contagem')
plt.title('Histograma cumulativo')
plt.show()
