# %% [markdown]
# <a href="https://colab.research.google.com/github/KeilaNLima/Material-da-Disciplina-prof.-Ricardo/blob/Gr%C3%A1fico_grade_malha_grid/C%C3%B3pia_de_MatplotLib_Legenda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Manipulando a grade (malha,grid)
# Keila Nunes de Lima
# Email: keilanuneslima1967@gmail.com
# 12/04/2023

# %%
# Importando Bibliotecas
import numpy as np
import matplotlib.pyplot as plt

# %%
# Criando variavel X
x = np.linspace(0,5,11)

# %%
# Criando funçoes y(x) e z(x)
y  = np.power(x-2,2.0)

# %%
z = np.exp(x/2.0)

# %%
# Criando uma grid
plt.plot(x,y,label='$Y(X)=(X-2)^2$')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('y(x)')
plt.grid(visible=True, linestyle = '--' , which = 'major' , color = 'grey') # O parametro B foi renomeado para visible.
plt.legend()
plt.show()

# %%
# Alterando a cor de fundo
plt.plot(x,y,label='$Y(X)=(X-2)^2$')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('y(x)')
plt.grid(visible=True , linestyle = '--' , which = 'major' , color = 'red')
plt.legend()
plt.show()

# %%
plt.plot(x,y,label='$Y(X)=(X-2)^2$')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('y(x)')
plt.grid(visible=True , linestyle = '--' , linewidth=2 , color = 'green')
plt.legend()
plt.show()
