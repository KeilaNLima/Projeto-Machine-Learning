# %% [markdown]
# <a href="https://colab.research.google.com/github/KeilaNLima/Material-da-Disciplina-prof.-Ricardo/blob/Gr%C3%A1fico_de_Torta/MatPlotLib_Gr%C3%A1fico_de_Torta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CRiando gráfico de Torta com a biblioteca MatPlotLib
# Keila Nunes de Lima
# email:keilanuneslima1967@gmail.com

# %%
# Importando bibliotecas

import numpy as np
import matplotlib.pyplot as plt

# %%
# Criando labels

labels = ('A1','A2','A3','A4','A4')

# %%
# Criando listas com valores
valores = [10,45,32,56,23]

# %%
plt.pie(valores,labels=labels,startangle=90)
plt.show()

# %%
plt.pie(valores,labels=labels,startangle=90,autopct='%1.1f%%')
plt.show()

# %%
# Inserindo porcentagem
plt.pie(valores,labels=labels,startangle=90, autopct='%1.1f%%' )
plt.title('Frequência dos dados do curso')
plt.show()

# %%
plt.pie(valores,labels=labels,startangle=180, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.pie(valores,labels=labels,startangle=90, autopct='%1.1f%%',shadow=True,explode=(0,0,1,0,0,))
plt.show()

# %%
plt.pie(valores,labels=labels,startangle=90, autopct='%1.1f%%',shadow=True,explode=(0,0,1,2,0,))
plt.show()
