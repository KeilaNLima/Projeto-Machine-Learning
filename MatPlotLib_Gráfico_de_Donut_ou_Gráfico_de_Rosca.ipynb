# %% [markdown]
# <a href="https://colab.research.google.com/github/KeilaNLima/Material-da-Disciplina-prof.-Ricardo/blob/Grafico_donut-rosca/MatPlotLib_Gr%C3%A1fico_de_Donut_ou_Gr%C3%A1fico_de_Rosca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criando gráfico de donutou gráfico de rosca com a biblioteca MatPlotLib
# Keila Nunes de Lima
# 15 abril 2023

# %%
# Importando Biblioteca
import numpy as np
import matplotlib.pyplot as plt

# %%
# Criando Labes
labels = ["Grupo 1","Grupo 2","Grupo 3","Grupo 4","Grupo 5"]

# %%
# Criando lista com valores
valores = [10,45,32,56,23]

# %%
# Criando lista com cores
cores = ['red','green','blue','orange','cyan']

# %%
# Definindo raio
raio = 0.7

# %%
# Criando grafico de barras
plt.pie(valores,labels=labels,colors=cores)
circulo = plt.Circle((0,0),raio,color='white')
p = plt.gcf()
p.gca().add_artist(circulo)
plt.show()

# %%
# adicionando porcentagem
plt.pie(valores,labels=labels,colors=cores,autopct='1%.1f%%')
circulo = plt.Circle((0,0),raio,color='white')
p = plt.gcf()
p.gca().add_artist(circulo)
plt.show()

# %%
raio = 0.4

# %%
plt.pie(valores,labels=labels,colors=cores,autopct='1%.1f%%')
circulo = plt.Circle((0,0),raio,color='pink')
p = plt.gcf()
p.gca().add_artist(circulo)
plt.show()
